# %% [markdown]
# Test Notebook

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#     ID                                              Title   Author  \
# 0  289  technology adoption model and a road map to su...    Ahmad
# 1  369      insights for the governance of large projects    Ahola
# 2  262  what is project governance and what are its or...    Ahola
# 3  310      the research frontier in corporate governance   Ahrens
# 4  433  information technology governance framework fo...  Ako-Nai
#
#                                             Abstract  \
# 0  purpose purpose this paper propose technology ...
# 1  purpose purpose this paper scrutinize influenc...
# 2  although there ever increasing discussion gove...
# 3  this paper attempt identify research frontier ...
# 4  background following corporate failures factor...
#
#                                     Topic_Keyphrases  Dominant_Topic  \
# 0  risk, result, service, relationship, increase,...             3.0
# 1  project, management, complexity, process, deve...             3.0
# ...
